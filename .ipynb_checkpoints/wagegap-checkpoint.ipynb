# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h1> Introduction </h1>
#
# The objective of this analysis is to determine if there is a wage gap between men and women in canada. The dataset used is from Statistics Canada, which is the federal statistical agency of Canada.
#
# Dataset: The dataset used in the analysis if from the
# 2011 National Household Survey (Catalogue Number:99-014-X2011042).

# %% [markdown]
# <h1> Cleaning the Data </h1>

# %%
# The occupation columns is organized hierarchically as follows:
# - entries with 1 digits before it's name represent the area of the occupations below
# - entries with 2 digits before it's name represent the subgroup of the occupations below
# - entries with 3 digits before it's name represent the industry of the occupations below
# - entries with 4 digits represent the occupations per se    
# Ex:
#     0 Management occupations
#       00 Senior management occupations
#         001 Legislators and senior management
#           0011 Legislators
# 
# the function clean does the job of cleaning the datasets


def set_index(df):
    group = ''
    subgroup = ''
    area = ''
    position = ''
    to_drop = []
    for index,row in df.iterrows():
        key = row['Occupation'].split()
        if len(key[0].split('-')[0]) == 1:
            group = ' '.join(key[1:])
            to_drop.append(index)
        elif len(key[0].split('-')[0]) == 2:
            subgroup = ' '.join(key[1:])
            to_drop.append(index)
        elif len(key[0].split('-')[0]) == 3:
            area = ' '.join(key[1:])
            to_drop.append(index)
        elif len(key[0].split('-')[0]) == 4:
            position = ' '.join(key[1:])
            df.loc[index,'Area'] = group
            df.loc[index,'SubGroup'] = subgroup
            df.loc[index,'Industry'] = area
            df.loc[index,'Position'] = position
    df = df.drop(df.index[to_drop]).drop('Occupation', axis=1)
    df = df.reset_index().drop(['index'], axis=1)
    #df = df.set_index(['Area','SubGroup','Industry','Position'])
    return df

def clean(dataset):
    df = pd.read_csv(filepath_or_buffer=dataset, skiprows=6, encoding = "ISO-8859-1")
    df = df.drop(df.index[[0, 1, 2, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704]])
    df.columns = ['Occupation', 'Total', 'WithIncome', 'MedEmpIncome', 'AvgEmpIncome', 'WithWage',
                  'MedWage', 'AvgWage', 'drop']
    
    df = df.drop('drop', axis=1)
    df['Area'] = ''
    df['SubGroup'] = ''
    df['Industry'] = ''
    df['Position'] = ''
    df = df.reset_index().drop(['index'], axis=1)
    return set_index(df)

# the dataframes df_male and df_female contain the information of male income and female income respectively

df_male = clean('male_income.csv')
df_female = clean('female_income.csv')

df_male['Gender'] = 'Male'
df_female['Gender'] = 'Female'

frames = [df_male, df_female]

df = pd.concat(frames).reset_index().drop(['index'], axis=1)

# %% [markdown]
# <h1> Exploring the data </h1>

# %%
# comparison between the average income of mens and womens
print(df.groupby('Gender').mean()['AvgEmpIncome'])
# Out:
# Gender
# Female    41592.242
# Male      54143.030
# Name: AvgEmpIncome, dtype: float64

# %%
plt.figure()
plt.title('Average Income (Male)')
sns.distplot(df[df['Gender']=='Male']['AvgEmpIncome'])
plt.savefig('male_distribution.png')

plt.figure()
plt.title('Average Income (Female)')
sns.distplot(df[df['Gender']=='Female']['AvgEmpIncome'])
plt.savefig('female_distribution.png')

plt.show()

# %%
# share of women per area

f, ax = plt.subplots(figsize=(10, 8))
sns.set(style="whitegrid")

sns.set_color_codes("pastel")
sns.barplot(x='Total', y='Area', data=df.groupby('Area').sum().sort_values('Total', ascending=False).reset_index(), 
            color='b', label='Total', ci=None)   

sns.set_color_codes("muted")
sns.barplot(x='Total', y='Area', 
            data=df[df['Gender']=='Female'].groupby('Area').sum().sort_values('Total', ascending=False).reset_index(), 
            color='b', label='Females', ci=None)   

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="People With Income")
sns.despine(left=True, bottom=True)

plt.savefig('females_per_area.png', bbox_inches='tight')
plt.show()

# %%
# shows how is the income is distributed along different areas

bins = [0, 30000, 50000, 70000, 100000, 210000]
df['Categories'] = pd.cut(df['AvgEmpIncome'], bins)

income_per_industry = df.groupby(['Area', 'Categories']).sum().dropna().reset_index()

normalizer = {income_per_industry['Area'].unique()[i] : 
              income_per_industry[income_per_industry['Area'] == income_per_industry['Area'].unique()[i]]['Total'].sum()
              for i in range(len(income_per_industry['Area'].unique()))}

income_per_industry['Fraction'] = 0

for i, row in income_per_industry.iterrows():
    income_per_industry.loc[i, 'Fraction'] = 100 * row['Total'] / normalizer[row['Area']]
    
colors = ['b', 'r', 'g', 'c', 'y']

f, ax = plt.subplots(figsize=(15, 8))
sns.set(style="whitegrid")

for i in range(4,-1,-1):
    sns.set_color_codes("bright")
    sns.barplot(y='Area', x='Fraction', label=income_per_industry['Categories'].unique()[i], estimator=sum, 
                data=income_per_industry[income_per_industry['Categories'].isin(income_per_industry['Categories'].unique()[:i+1])], 
                color=colors[i], ci=None)   

ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set_xlim(0,140)
ax.set(xlabel="Percentage")
sns.despine(left=True, bottom=True)

# plt.savefig('income_per_area.png', bbox_inches='tight')
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 8))
ax2 = ax.twinx()
sns.set(style="whitegrid")

order = df['Area'].unique().tolist()

sns.pointplot(x='Area', y='AvgEmpIncome', ci=None, ax=ax2, hue='Gender', order=order, 
              data=df.groupby(['Area','Gender']).mean().reset_index())

sns.set_color_codes("pastel")
sns.barplot(x='Area', y='Total', ci=None, ax=ax, color='lightblue', label='Total', order=order,
              data=df.groupby(['Area']).sum().reset_index())

sns.set_color_codes("muted")
sns.barplot(x='Area', y='Total', ci=None, ax=ax, color='blue', label='Female', order=order,
              data=df[df['Gender'] == 'Female'].groupby(['Area']).sum().reset_index())

ax.set_ylabel('Total per Area')
ax2.set_ylabel('Average Income per Area')
ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set_xticklabels(labels=order, rotation='vertical')
ax2.set_xticklabels(labels=order, rotation='vertical')
plt.savefig('total_income_area.png')
plt.show()

# %%
# share of women per subgroup

f, ax = plt.subplots(figsize=(10, 10))
sns.set(style="whitegrid")

sns.set_color_codes("pastel")
sns.barplot(x='Total', y='SubGroup', data=df.groupby('SubGroup').sum().sort_values('Total', ascending=False).reset_index(), 
            color='b', label='Total', ci=None)   

sns.set_color_codes("muted")
sns.barplot(x='Total', y='SubGroup', 
            data=df[df['Gender']=='Female'].groupby('SubGroup').sum().sort_values('Total', ascending=False).reset_index(), 
            color='b', label='Females', ci=None)   

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="People With Income")
sns.despine(left=True, bottom=True)

plt.savefig('females_per_sg.png', bbox_inches='tight')
plt.show()

# %%
# shows how is the income is distributed along different subgroups

income_per_sg = df.groupby(['SubGroup', 'Categories']).sum().dropna().reset_index()

normalizer = {income_per_sg['SubGroup'].unique()[i] : 
              income_per_sg[income_per_sg['SubGroup'] == income_per_sg['SubGroup'].unique()[i]]['Total'].sum()
              for i in range(len(income_per_sg['SubGroup'].unique()))}

income_per_sg['Fraction'] = 0

for i, row in income_per_sg.iterrows():
    income_per_sg.loc[i, 'Fraction'] = 100 * row['Total'] / normalizer[row['SubGroup']]
    
colors = ['b', 'r', 'g', 'c', 'y']

f, ax = plt.subplots(figsize=(15, 8))
sns.set(style="whitegrid")

for i in range(4,-1,-1):
    sns.set_color_codes("bright")
    sns.barplot(y='SubGroup', x='Fraction', label=income_per_sg['Categories'].unique()[i], estimator=sum, 
                data=income_per_sg[income_per_sg['Categories'].isin(income_per_sg['Categories'].unique()[:i+1])], 
                color=colors[i], ci=None)   

ax.legend(ncol=2, loc="upper right", frameon=True)
ax.set_xlim(0,140)
ax.set(xlabel="Percentage")
sns.despine(left=True, bottom=True)

plt.savefig('income_per_sg.png', bbox_inches='tight')
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 8))
ax2 = ax.twinx()
sns.set(style="whitegrid")

order = df['SubGroup'].unique().tolist()

sns.pointplot(x='SubGroup', y='AvgEmpIncome', ci=None, ax=ax2, hue='Gender', order=order,
              data=df.groupby(['SubGroup','Gender']).mean().reset_index())

sns.set_color_codes("bright")
sns.barplot(x='SubGroup', y='Total', ci=None, ax=ax, color='lightblue', order=order, label='Total',
              data=df.groupby(['SubGroup']).sum().reset_index())

sns.set_color_codes("muted")
sns.barplot(x='SubGroup', y='Total', ci=None, ax=ax, color='blue', label='Female', order=order,
              data=df[df['Gender'] == 'Female'].groupby(['SubGroup']).sum().reset_index())

ax.set_ylabel('Total per SubGroup')
ax2.set_ylabel('Average Income per SubGroup')
ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set_xticklabels(labels=order, rotation='vertical')
ax2.set_xticklabels(labels=order, rotation='vertical')
plt.savefig('total_income_subgroup.png')
plt.show()

# %%
# define a new column called type of income
# this column is binary and has values high (income > 50k/year) or low (income <= 50k/year)
# the goal of this new column is to determine the percentage of women who have high paying jobs and the percentage
# of women out of the people with high paying jobs according to the criteria

df['TypeOfIncome'] = df.apply(lambda row: 'High' if row['AvgEmpIncome'] > 50000 else 'Low', axis=1)


print('Percentage of women out of the people with high paying jobs: {0}'.format(
        100 * df[(df['Gender'] == 'Female') & (df['TypeOfIncome'] == 'High')]['Total'].sum() / 
        df[(df['TypeOfIncome'] == 'High')]['Total'].sum()))

print('Percentage of women with high paying jobs: {0}'.format(
        100 * df[(df['Gender'] == 'Female') & (df['TypeOfIncome'] == 'High')]['Total'].sum() / 
        df[(df['Gender'] == 'Female')]['Total'].sum()))
# Out:
# Percentage of women out of the people with high paying jobs: 33.380373383341855
# Percentage of women with high paying jobs: 23.069253893676063

# %%
f, ax = plt.subplots(figsize=(15, 8))
ax2 = ax.twinx()
sns.set(style="whitegrid")
high_pay = (df.groupby(['Position'])
            .mean()
            .sort_values(by='AvgEmpIncome', ascending=False)
            .reset_index()
            .head(20))['Position']
order = high_pay.tolist()

sns.pointplot(x='Position', y='AvgEmpIncome', ci=None, ax=ax2, hue='Gender', order=order,
              data=df[df['Position'].isin(high_pay)])
              
sns.set_color_codes("pastel")
sns.barplot(x='Position', y='Total', ci=None, ax=ax, color='lightblue', label='Total', order=order,
            data=df[df['Position'].isin(high_pay)].groupby(['Position']).sum().reset_index())
            
sns.set_color_codes("muted")
sns.barplot(x='Position', y='Total', ci=None, ax=ax, color='blue', label='Female', order=order,
            data=df[df['Position'].isin(high_pay)][df['Gender'] == 'Female'])
            
ax.set_ylabel('Total per Position')
ax2.set_ylabel('Average Income per Position')
ax.legend(ncol=2, loc="upper left", frameon=True)
ax.set_xticklabels(labels=order, rotation='vertical')
ax2.set_xticklabels(labels=order, rotation='vertical')
plt.savefig('total_income_top_position.png')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# <h1> Ratio Analysis </h1>

# %%
# in order to determine if there is a wage gap I created a new dataframe with information about the rate between
# female income and male income for people who have the same position in the same industry, subgroup and area

df2 = df_male.merge(df_female, how='inner', on=['Area', 'SubGroup', 'Industry', 'Position'], suffixes=('_M','_F'))
df2['Ratio'] = df2['AvgEmpIncome_F'] / df2['AvgEmpIncome_M']
ratio = df2[['Area', 'SubGroup', 'Industry', 'Position', 'Ratio', 'Total_M', 'Total_F']]

print('Positions where women earn more than men on average: \n {0}'.format(ratio[ratio['Ratio'] >= 1]['Position'].tolist()))
# Out:
# Positions where women earn more than men on average:
#  ['Legal administrative assistants', 'Court reporters, medical transcriptionists and related occupations', 'Receptionists', 'Data entry clerks', 'Library assistants and clerks', 'Information systems testing technicians', 'Dental assistants', 'Paralegal and related occupations', 'Dancers', 'Library and public archive technicians', 'Cooks', 'Cashiers', 'Store shelf stockers, clerks and order fillers', 'Food counter attendants, kitchen helpers and related support occupations', 'Power system electricians', 'Roofers and shinglers', 'Contractors and supervisors, heavy equipment operator crews', 'Chain saw and skidder operators', 'Trappers and hunters']

# %%
ratio.groupby('Area').mean().sort_values('Ratio').reset_index()
# Out:
#                                                 Area     Ratio       Total_M  \
# 0  Natural resources, agriculture and related pro...  0.713070  15252.291667
# 1         Occupations in manufacturing and utilities  0.751236   8526.901408
# 2                             Management occupations  0.753773  26704.791667
# 3  Trades, transport and equipment operators and ...  0.770387  31850.812500
# 4  Occupations in art, culture, recreation and sport  0.778680   8277.727273
# 5  Natural and applied sciences and related occup...  0.783415  16421.370968
# 6                                 Health occupations  0.787711   6352.222222
# 7                      Sales and service occupations  0.805058  35954.907407
# 8   Business, finance and administration occupations  0.832592  17087.129630
# 9  Occupations in education, law and social, comm...  0.853489  19339.868421
#
#         Total_F
# 0   3953.958333
# 1   3736.267606
# 2  16132.604167
# 3   2119.375000
# 4   9641.969697
# 5   4652.419355
# 6  26308.333333
# 7  48506.851852
# 8  41132.500000
# 9  39851.315789

# %%
# ratio per area

f, ax = plt.subplots(figsize=(15, 8))
sns.set(style="whitegrid")

sns.set_color_codes("bright")
sns.barplot(x='Ratio', y='Area', 
            data=ratio.groupby('Area').mean().sort_values('Ratio', ascending=False).reset_index(), 
            ci=None, color='blue')   

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="Average Ratio per Area")
sns.despine(left=True, bottom=True)
ax.set_xlim([0,1])

plt.savefig('ratio_per_area.png', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
#ratio per subgroup

f, ax = plt.subplots(figsize=(15, 8))
sns.set(style="whitegrid")

sns.set_color_codes("bright")
sns.barplot(x='Ratio', y='SubGroup', 
            data=ratio.groupby('SubGroup').mean().sort_values('Ratio', ascending=False).reset_index(), 
            ci=None, color='blue')   

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlabel="Average Ratio per Sub Group")
sns.despine(left=True, bottom=True)
ax.set_xlim([0,1])

plt.savefig('ratio_per_sg.png', bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
print('Positions with least ratios:')
(ratio
 .sort_values('Ratio', ascending=True)
 .reset_index()
 .drop(['index', 'Area', 'SubGroup', 'Industry'], axis=1).head(10))
# Out:
# Positions with least ratio:
#                                             Position     Ratio  Total_M  \
# 0                                           Athletes  0.158363   3365.0
# 1                       Fishing masters and officers  0.413097   2790.0
# 2  Securities agents, investment dealers and brokers  0.460758  12420.0
# 3  Agricultural service contractors, farm supervi...  0.461337   7185.0
# 4                           Managers in horticulture  0.488123   3150.0
# 5      Banking, credit and other investment managers  0.490286  33820.0
# 6                        Logging machinery operators  0.495047  10830.0
# 7                   Geoscientists and oceanographers  0.520811  11185.0
# 8  Motorcycle, all-terrain vehicle and other rela...  0.527924   5305.0
# 9        Papermaking and finishing machine operators  0.536995   2950.0
#
#    Total_F
# 0    565.0
# 1    115.0
# 2   5980.0
# 3   3535.0
# 4   1975.0
# 5  44655.0
# 6    240.0
# 7   3220.0
# 8     25.0
# 9    480.0

# %% [markdown]
# <h1> Hypothesis Testing </h1>

# %%
from scipy.stats import ttest_ind, ttest_1samp

def hypothesis_test(ratio, alpha=0.01):
    '''
    H0: There is no wage gap, meaning that the average ratio between the incomes of women and men is equal to 1
    H1: There is a wage gap, meaning that the average ratio between the incomes of women and men is less than 1
    
    To determine which hypothesis is true a t-Student test is performed with significance alpha
    OBS: we have to check the value of the p-value over 2 as we are performing an one-sided test
    '''
    tstat, pval = ttest_1samp(ratio, 1)
    if pval/2 < alpha:
        print('The evidence provided by the data indicates the existance of a wage gap')
    else:
        print('The evidence provided by the data does not indicate the existance of a wage gap')
    return pval/2
    
hypothesis_test(ratio['Ratio'])
# Out:
# The evidence provided by the data indicates the existance of a wage gap
# 8.8818700685223632e-160

# %%
plt.figure()
plt.title('Ratio between income (F/M)')
sns.distplot(ratio['Ratio'])

plt.savefig('ratio_dist.png')
plt.show()
